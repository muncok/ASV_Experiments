# %% [markdown]
# Auto-Encoder
# ---------------------------------
#
# 경미의 [논문](https://drive.google.com/file/d/1RArk7z4NqY5HkwkUWx4cR2ApZNnAQxdF/view?usp=sharing)에 따르면 AE가 좀더 generalize한 feature를 뽑아준다고한다. 물론 image에 대해서 실험했고 (28x28, 32x32 의 작은...) task 간의 generalization에 대해 언급해서 조금 context가 다르다.
#
# 그래서 일단 xvector의 feature를 가지고 간단한게 AE를 구현해보려고한다.

# %% [markdown]
# Center-Loss
# ----------------------
#
# Auto-Encoder의 MSELoss에 Center loss를 넣어서 더 모이게 한다면 어떻게 될까?
#
# Unsupervise에서 Supervise로 된거다.
#
# 관찰:
# - cent_lr을 0.1까지 줄였더니... eer이 20%넘게까지 올라간다..

# %% [markdown]
# Faster
# ---------------
#
# 현재 centroid가 너무 많아서 연산이 오래걸린다.
# 하지만 실제로 사용하는 centroid는 batch에 존재하는 class들이다.
#
# 그래프를 깨지 않으면서 효율적으로 연산하는 방법을 생각해보자.

# %% [markdown]
# ### Environment

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab
# %matplotlib inline

import pandas as pd
import pickle
import numpy as np
import sys
import os
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.append('../')
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ### AE Model

# %%
import torch
import torch.nn as nn

class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(512, 400),
            nn.ReLU(True),
            nn.Linear(400, 300),
            nn.ReLU(True), nn.Linear(300, 256), nn.ReLU(True), nn.Linear(256, 128))
        self.decoder = nn.Sequential(
            nn.Linear(128, 256),
            nn.ReLU(True),
            nn.Linear(256, 300),
            nn.ReLU(True),
            nn.Linear(300, 400),
            nn.ReLU(True), nn.Linear(400, 512), nn.Tanh())
        
        self.latent_dim = 128

    def forward(self, x):
        latent = self.encoder(x)
        output = self.decoder(latent)
        return latent, output
    
    def embed(self, x):
        latent = self.encoder(x)
        return latent

# %% [markdown]
# ### Center-Loss

# %%
import torch                                                                                                                                                                                                                                                                 
import torch.nn as nn                                                                                                                                                                                                                                                        

class CenterLoss(nn.Module):                                                                                                                                                                                                                                                 
    """Center loss.                                                                                                                                                                                                                                                          

    Reference:                                                                                                                                                                                                                                                               
    Wen et al. A Discriminative Feature Learning Approach for Deep Face Recognition. ECCV 2016.                                                                                                                                                                              

    Args:                                                                                                                                                                                                                                                                    
     num_classes (int): number of classes.                                                                                                                                                                                                                                
     feat_dim (int): feature dimension.                                                                                                                                                                                                                                   
    """                                                                                                                                                                                                                                                                      
    def __init__(self, num_classes, feat_dim, use_gpu=True):                                                                                                                                                                                                            
        super(CenterLoss, self).__init__()                                                                                                                                                                                                                                   
        self.num_classes = num_classes                                                                                                                                                                                                                                       
        self.feat_dim = feat_dim                                                                                                                                                                                                                                             
        self.use_gpu = use_gpu                                                                                                                                                                                                                                               

        if self.use_gpu:                                                                                                                                                                                                                                                     
            self.centers = nn.Parameter(torch.randn(self.num_classes, self.feat_dim).cuda())                                                                                                                                                                                 
        else:                                                                                                                                                                                                                                                                
            self.centers = nn.Parameter(torch.randn(self.num_classes, self.feat_dim))                                                                                                                                                                                        

    def forward(self, x, labels):                                                                                                                                                                                                                                            
        """                                                                                                                                                                                                                                                                  
        Args:                                                                                                                                                                                                                                                                
         x: feature matrix with shape (batch_size, feat_dim).  |                                                                                                                                                                                                           
         labels: ground truth labels with shape (num_classes).                                                                                                                                                                                                            
        """                                                                                                                                                                                                                                                                  
        batch_size = x.size(0)                                                                                                                                                                                                                                               

        centers_for_batch = self.centers[labels]
        distvec = torch.pow(x, 2).sum(dim=1) + torch.pow(centers_for_batch, 2).sum(dim=1)
#         print(distvec.shape, x.shape, centers_for_batch.shape)
        distvec += torch.sum(-2*x*centers_for_batch, dim=1)
        distvec.clamp(min=1e-12, max=1e+12) 
                                         
        loss = distvec.mean()                                                                                                                                                                                                                                                   

        return loss

# %% [markdown]
# ### Dataset

# %%
import torch.utils.data as data

class embedDataset(data.Dataset):
    def __init__(self, embeds, labels):
        super().__init__()
        self.embeds = embeds
        self.labels = labels
        
    def __getitem__(self, index):
        
        return self.embeds[index], self.labels[index]
    
    def __len__(self):
        
        return self.embeds.shape[0]

def embedToDataset(embeds, key_df):
    labels = key_df.label.tolist()
    dataset = embedDataset(embeds, labels)
    
    return dataset, embeds.shape[1], len(key_df.label.unique())

def key2df(keys):
    key_df = pd.DataFrame(keys, columns=['key'])
    key_df['spk'] = key_df.key.apply(lambda x: x.split("-")[0])
    key_df['label'] = key_df.groupby('spk').ngroup()
    key_df['origin'] = key_df.spk.apply(lambda x: 'voxc2' if x.startswith('id') else 'voxc1')
    
    return key_df

# %%
trial = pd.read_pickle("../dataset/dataframes/voxc1/voxc_trial.pkl")

# si_set
si_keys = pickle.load(open("../embeddings/voxc12/xvectors/xvectors_tdnn6b/train_feat/key.pkl", "rb"))
si_embeds = np.load("../embeddings/voxc12/xvectors/xvectors_tdnn6b/train_feat/feat.npy")
si_key_df = key2df(si_keys)

# sv_set
sv_keys = pickle.load(open("../embeddings/voxc12/xvectors/xvectors_tdnn6b/test_feat/key.pkl", "rb"))
sv_embeds = np.load("../embeddings/voxc12/xvectors/xvectors_tdnn6b/test_feat/feat.npy")
sv_key_df = key2df(sv_keys)

# %%
si_dataset, embed_dim, n_labels = embedToDataset(si_embeds, si_key_df)
sv_dataset, _, _ = embedToDataset(sv_embeds, sv_key_df)

# %% [markdown]
# ### Training

# %%
import torch.nn.functional as F
from sklearn.metrics import roc_curve

def embeds_utterance(val_dataloader, model):
    embeddings = []
    labels = []
    if torch.cuda.is_available():
            model = model.cuda()
    model.eval()

    with torch.no_grad():
        for batch in val_dataloader:
            X, y = batch
            if not no_cuda:
                X = X.cuda()
                model = model.cuda()
                
            model_output = model.embed(X).cpu().detach()
            embeddings.append(model_output)
            labels.append(y.numpy())
        embeddings = torch.cat(embeddings)
        labels = np.hstack(labels)
    return embeddings, labels 

def sv_test(sv_loader, model, trial):
    embeddings, _ = embeds_utterance(sv_loader, model)
    trial_enroll = embeddings[trial.enrolment_id.tolist()]
    trial_test = embeddings[trial.test_id.tolist()]

    score_vector = F.cosine_similarity(trial_enroll, trial_test, dim=1)
    label_vector = np.array(trial.label)
    fpr, tpr, thres = roc_curve(
            label_vector, score_vector, pos_label=1)
    eer = fpr[np.nanargmin(np.abs(fpr - (1 - tpr)))]

    return eer

# %%
num_epochs = 100
batch_size = 32
learning_rate = 1e-3
no_cuda = False

# %%
model = autoencoder().cuda()

# %%
import torch

weight_cent = 0.01 
criterion_ae = nn.MSELoss()
criterion_cent = CenterLoss(num_classes=7324, feat_dim=model.latent_dim, use_gpu=(not no_cuda))
optimizer_ae = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=1e-05, momentum=0.9)
optimizer_cent = torch.optim.SGD(criterion_cent.parameters(), lr=0.5)

# %%
from torch.utils.data.dataloader import DataLoader

si_loader = DataLoader(si_dataset, num_workers=0, batch_size=batch_size, 
                           drop_last=True, pin_memory=True)

sv_loader = DataLoader(sv_dataset, batch_size=batch_size, num_workers=0, shuffle=False)

# %%
if not no_cuda:
    model = model.cuda()
    
for epoch in range(num_epochs):
    loss_sum = 0
    total = 0
    for batch_idx, (X, y) in enumerate(si_loader):
        model.train()
        if not no_cuda:
            X = X.cuda()
            y = y.cuda()
        # ===================forward=====================
        latent, output = model(X)
        loss_ae = criterion_ae(output, X)
        loss_cent = criterion_cent(latent, y)
        loss_cent *= weight_cent
        loss = loss_ae + loss_cent
        # ===================backward====================
        optimizer_ae.zero_grad()
        optimizer_cent.zero_grad()
        loss.backward()
        
        optimizer_ae.step()
        for param in criterion_cent.parameters():                                                                                 
            param.grad.data *= (1. / weight_cent)
        optimizer_cent.step()
        
#         loss_sum += loss.item()
#         total += X.size(0)
#         if batch_idx % 100 == 0:
#             print(f"train loss: {loss_sum/total}")
   
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}, ae_loss:{:.4f}, cent_loss:{:.4f}'
          .format(epoch + 1, num_epochs, loss.item(), loss_ae.item(), loss_cent.item()))
    
    # =================sv_loss======================
    for batch_idx, (X, y)  in enumerate(sv_loader):
        model.eval()
        if not no_cuda:
                X = X.cuda()
                y.cuda()
        latent, output = model(X)
        loss_ae = criterion_ae(output, X)
        loss_cent = criterion_cent(latent, y)
        loss_cent *= weight_cent
        loss = loss_ae + loss_cent
    eer = sv_test(sv_loader, model, trial)
    print("sv loss: {:.4f}, sv eer: {:.4f}".format(loss.item(), eer))
# Out:
# epoch [1/100], loss:0.8955, ae_loss:0.8951, cent_loss:0.0004
# sv loss: 0.8954, sv eer: 0.1780
# epoch [2/100], loss:0.8942, ae_loss:0.8937, cent_loss:0.0004
# sv loss: 0.8940, sv eer: 0.1779
# epoch [3/100], loss:0.8929, ae_loss:0.8924, cent_loss:0.0004
# sv loss: 0.8927, sv eer: 0.1783
# epoch [4/100], loss:0.8916, ae_loss:0.8911, cent_loss:0.0004
# sv loss: 0.8914, sv eer: 0.1783
# epoch [5/100], loss:0.8903, ae_loss:0.8898, cent_loss:0.0004
# sv loss: 0.8901, sv eer: 0.1781
# epoch [6/100], loss:0.8890, ae_loss:0.8886, cent_loss:0.0004
# sv loss: 0.8888, sv eer: 0.1783
# epoch [7/100], loss:0.8877, ae_loss:0.8873, cent_loss:0.0004
# sv loss: 0.8876, sv eer: 0.1782
# epoch [8/100], loss:0.8865, ae_loss:0.8860, cent_loss:0.0004
# sv loss: 0.8863, sv eer: 0.1785
# epoch [9/100], loss:0.8852, ae_loss:0.8848, cent_loss:0.0004
# sv loss: 0.8851, sv eer: 0.1783
# epoch [10/100], loss:0.8840, ae_loss:0.8836, cent_loss:0.0004
# sv loss: 0.8839, sv eer: 0.1788
# ...

# %%
torch.save(model.state_dict(), open("saved_models/center_ae_test.pt", "wb"))

# %% [raw]
# tdnn7b result
# -------------------
#
# epoch [1/100], loss:2.1263, ae_loss:0.9302, cent_loss:1.1960
# sv loss: 1.3220, sv eer: 0.4110
# epoch [2/100], loss:0.9351, ae_loss:0.9310, cent_loss:0.0041
# sv loss: 1.0727, sv eer: 0.4043
# epoch [3/100], loss:0.9317, ae_loss:0.9315, cent_loss:0.0001
# sv loss: 1.0153, sv eer: 0.4072
# epoch [4/100], loss:0.9318, ae_loss:0.9317, cent_loss:0.0001
# sv loss: 1.0022, sv eer: 0.3914
# epoch [5/100], loss:0.9240, ae_loss:0.9234, cent_loss:0.0006
# sv loss: 0.9866, sv eer: 0.4106
# epoch [6/100], loss:0.9070, ae_loss:0.9067, cent_loss:0.0003
# sv loss: 0.9453, sv eer: 0.3366
# epoch [7/100], loss:0.8997, ae_loss:0.8995, cent_loss:0.0002
# sv loss: 0.9271, sv eer: 0.2887
# epoch [8/100], loss:0.9057, ae_loss:0.9056, cent_loss:0.0002
# sv loss: 0.9339, sv eer: 0.2777
# epoch [9/100], loss:0.9040, ae_loss:0.9037, cent_loss:0.0002
# sv loss: 0.9406, sv eer: 0.2906
# epoch [10/100], loss:0.8860, ae_loss:0.8844, cent_loss:0.0017
# sv loss: 0.9371, sv eer: 0.2891
# epoch [11/100], loss:0.8768, ae_loss:0.8761, cent_loss:0.0007
# sv loss: 0.9159, sv eer: 0.2670
# epoch [12/100], loss:0.8556, ae_loss:0.8543, cent_loss:0.0013
# sv loss: 0.9005, sv eer: 0.2332
# epoch [13/100], loss:0.8410, ae_loss:0.8404, cent_loss:0.0006
# sv loss: 0.9044, sv eer: 0.1973
# epoch [14/100], loss:0.8288, ae_loss:0.8279, cent_loss:0.0009
# sv loss: 0.8955, sv eer: 0.1927
# epoch [15/100], loss:0.8164, ae_loss:0.8151, cent_loss:0.0013
# sv loss: 0.8864, sv eer: 0.1903
# epoch [16/100], loss:0.8010, ae_loss:0.7996, cent_loss:0.0014
# sv loss: 0.8746, sv eer: 0.1830
# epoch [17/100], loss:0.7826, ae_loss:0.7816, cent_loss:0.0010
# sv loss: 0.8574, sv eer: 0.1786
# epoch [18/100], loss:0.7703, ae_loss:0.7695, cent_loss:0.0009
# sv loss: 0.8459, sv eer: 0.1784
# epoch [19/100], loss:0.7624, ae_loss:0.7616, cent_loss:0.0008
# sv loss: 0.8404, sv eer: 0.1762
# epoch [20/100], loss:0.7556, ae_loss:0.7548, cent_loss:0.0008
# sv loss: 0.8335, sv eer: 0.1731
# epoch [21/100], loss:0.7516, ae_loss:0.7507, cent_loss:0.0009
# sv loss: 0.8243, sv eer: 0.1666
# epoch [22/100], loss:0.7447, ae_loss:0.7435, cent_loss:0.0012
# sv loss: 0.8068, sv eer: 0.1620
# epoch [23/100], loss:0.7405, ae_loss:0.7394, cent_loss:0.0011
# sv loss: 0.7962, sv eer: 0.1640
# epoch [24/100], loss:0.7388, ae_loss:0.7377, cent_loss:0.0011
# sv loss: 0.7919, sv eer: 0.1621
# epoch [25/100], loss:0.7368, ae_loss:0.7356, cent_loss:0.0012
# sv loss: 0.7859, sv eer: 0.1597
# epoch [26/100], loss:0.7360, ae_loss:0.7348, cent_loss:0.0012
# sv loss: 0.7842, sv eer: 0.1569
# epoch [27/100], loss:0.7329, ae_loss:0.7316, cent_loss:0.0013
# sv loss: 0.7854, sv eer: 0.1552
# epoch [28/100], loss:0.7308, ae_loss:0.7295, cent_loss:0.0013
# sv loss: 0.7870, sv eer: 0.1566
# epoch [29/100], loss:0.7282, ae_loss:0.7269, cent_loss:0.0013
# sv loss: 0.7901, sv eer: 0.1572
# epoch [30/100], loss:0.7261, ae_loss:0.7248, cent_loss:0.0013
# sv loss: 0.7944, sv eer: 0.1543
# epoch [31/100], loss:0.7260, ae_loss:0.7243, cent_loss:0.0017
# sv loss: 0.7873, sv eer: 0.1599
# epoch [32/100], loss:0.7184, ae_loss:0.7169, cent_loss:0.0015
# sv loss: 0.7798, sv eer: 0.1610
# epoch [33/100], loss:0.7135, ae_loss:0.7121, cent_loss:0.0014
# sv loss: 0.7555, sv eer: 0.1587
# epoch [34/100], loss:0.7101, ae_loss:0.7088, cent_loss:0.0013
# sv loss: 0.7547, sv eer: 0.1582
# epoch [35/100], loss:0.7077, ae_loss:0.7064, cent_loss:0.0013
# sv loss: 0.7485, sv eer: 0.1570
# epoch [36/100], loss:0.7069, ae_loss:0.7056, cent_loss:0.0013
# sv loss: 0.7519, sv eer: 0.1534
# epoch [37/100], loss:0.7061, ae_loss:0.7048, cent_loss:0.0013
# sv loss: 0.7513, sv eer: 0.1526
# epoch [38/100], loss:0.7049, ae_loss:0.7036, cent_loss:0.0013
# sv loss: 0.7495, sv eer: 0.1537
# epoch [39/100], loss:0.7003, ae_loss:0.6988, cent_loss:0.0015
# sv loss: 0.7536, sv eer: 0.1548
# epoch [40/100], loss:0.7003, ae_loss:0.6987, cent_loss:0.0016
# sv loss: 0.7524, sv eer: 0.1531
# epoch [41/100], loss:0.6978, ae_loss:0.6962, cent_loss:0.0016
# sv loss: 0.7432, sv eer: 0.1483
# epoch [42/100], loss:0.6969, ae_loss:0.6954, cent_loss:0.0015
# sv loss: 0.7410, sv eer: 0.1410
# epoch [43/100], loss:0.6987, ae_loss:0.6972, cent_loss:0.0015
# sv loss: 0.7325, sv eer: 0.1422
# epoch [44/100], loss:0.6975, ae_loss:0.6960, cent_loss:0.0014
# sv loss: 0.7325, sv eer: 0.1450
# epoch [45/100], loss:0.6988, ae_loss:0.6974, cent_loss:0.0014
# sv loss: 0.7307, sv eer: 0.1459
# epoch [46/100], loss:0.6979, ae_loss:0.6965, cent_loss:0.0014
# sv loss: 0.7266, sv eer: 0.1469
# epoch [47/100], loss:0.7004, ae_loss:0.6989, cent_loss:0.0015
# sv loss: 0.7295, sv eer: 0.1434
# epoch [48/100], loss:0.6983, ae_loss:0.6968, cent_loss:0.0015
# sv loss: 0.7246, sv eer: 0.1443
# epoch [49/100], loss:0.6996, ae_loss:0.6980, cent_loss:0.0016
# sv loss: 0.7248, sv eer: 0.1546
# epoch [50/100], loss:0.7016, ae_loss:0.6999, cent_loss:0.0017
# sv loss: 0.7200, sv eer: 0.1482
# epoch [51/100], loss:0.6996, ae_loss:0.6980, cent_loss:0.0015
# sv loss: 0.7217, sv eer: 0.1498
# epoch [52/100], loss:0.6989, ae_loss:0.6973, cent_loss:0.0017
# sv loss: 0.7201, sv eer: 0.1460
# epoch [53/100], loss:0.6956, ae_loss:0.6938, cent_loss:0.0018
# sv loss: 0.7160, sv eer: 0.1486
# epoch [54/100], loss:0.6963, ae_loss:0.6944, cent_loss:0.0019
# sv loss: 0.7172, sv eer: 0.1533
# epoch [55/100], loss:0.6958, ae_loss:0.6940, cent_loss:0.0018
# sv loss: 0.7112, sv eer: 0.1506
# epoch [56/100], loss:0.6949, ae_loss:0.6930, cent_loss:0.0019
# sv loss: 0.7179, sv eer: 0.1398
# epoch [57/100], loss:0.6943, ae_loss:0.6923, cent_loss:0.0020
# sv loss: 0.7229, sv eer: 0.1326
# epoch [58/100], loss:0.6874, ae_loss:0.6853, cent_loss:0.0020
# sv loss: 0.7228, sv eer: 0.1268
# epoch [59/100], loss:0.6880, ae_loss:0.6858, cent_loss:0.0021
# sv loss: 0.7121, sv eer: 0.1293
# epoch [60/100], loss:0.6877, ae_loss:0.6857, cent_loss:0.0020
# sv loss: 0.7028, sv eer: 0.1291
# epoch [61/100], loss:0.6861, ae_loss:0.6843, cent_loss:0.0018
# sv loss: 0.7043, sv eer: 0.1312
# epoch [62/100], loss:0.6868, ae_loss:0.6850, cent_loss:0.0018
# sv loss: 0.7002, sv eer: 0.1284
# epoch [63/100], loss:0.6864, ae_loss:0.6846, cent_loss:0.0018
# sv loss: 0.7027, sv eer: 0.1303
# epoch [64/100], loss:0.6849, ae_loss:0.6832, cent_loss:0.0017
# sv loss: 0.6983, sv eer: 0.1298
# epoch [65/100], loss:0.6846, ae_loss:0.6830, cent_loss:0.0016
# sv loss: 0.6974, sv eer: 0.1288
# epoch [66/100], loss:0.6843, ae_loss:0.6827, cent_loss:0.0016
# sv loss: 0.6997, sv eer: 0.1307
# epoch [67/100], loss:0.6824, ae_loss:0.6809, cent_loss:0.0015
# sv loss: 0.6984, sv eer: 0.1290
# epoch [68/100], loss:0.6830, ae_loss:0.6814, cent_loss:0.0015
# sv loss: 0.6987, sv eer: 0.1310
# epoch [69/100], loss:0.6833, ae_loss:0.6816, cent_loss:0.0017
# sv loss: 0.6993, sv eer: 0.1354
# epoch [70/100], loss:0.6796, ae_loss:0.6778, cent_loss:0.0018
# sv loss: 0.6974, sv eer: 0.1354
# epoch [71/100], loss:0.6811, ae_loss:0.6793, cent_loss:0.0018
# sv loss: 0.6991, sv eer: 0.1361
# epoch [72/100], loss:0.6798, ae_loss:0.6779, cent_loss:0.0018
# sv loss: 0.6960, sv eer: 0.1347
# epoch [73/100], loss:0.6777, ae_loss:0.6759, cent_loss:0.0017
# sv loss: 0.6947, sv eer: 0.1337
# epoch [74/100], loss:0.6743, ae_loss:0.6725, cent_loss:0.0018
# sv loss: 0.6880, sv eer: 0.1341
# epoch [75/100], loss:0.6751, ae_loss:0.6734, cent_loss:0.0017
# sv loss: 0.6918, sv eer: 0.1318
# epoch [76/100], loss:0.6761, ae_loss:0.6744, cent_loss:0.0018
# sv loss: 0.6905, sv eer: 0.1313
# epoch [77/100], loss:0.6722, ae_loss:0.6706, cent_loss:0.0016
# sv loss: 0.6843, sv eer: 0.1309
# epoch [78/100], loss:0.6737, ae_loss:0.6720, cent_loss:0.0017
# sv loss: 0.6856, sv eer: 0.1288
# epoch [79/100], loss:0.6701, ae_loss:0.6685, cent_loss:0.0016
# sv loss: 0.6844, sv eer: 0.1293
# epoch [80/100], loss:0.6756, ae_loss:0.6740, cent_loss:0.0017
# sv loss: 0.6820, sv eer: 0.1274
# epoch [81/100], loss:0.6698, ae_loss:0.6681, cent_loss:0.0017
# sv loss: 0.6806, sv eer: 0.1266
# epoch [82/100], loss:0.6690, ae_loss:0.6672, cent_loss:0.0018
# sv loss: 0.6783, sv eer: 0.1271
# epoch [83/100], loss:0.6716, ae_loss:0.6696, cent_loss:0.0020
# sv loss: 0.6731, sv eer: 0.1321
# epoch [84/100], loss:0.6635, ae_loss:0.6616, cent_loss:0.0019
# sv loss: 0.6725, sv eer: 0.1324
# epoch [85/100], loss:0.6646, ae_loss:0.6625, cent_loss:0.0021
# sv loss: 0.6660, sv eer: 0.1399
# epoch [86/100], loss:0.6633, ae_loss:0.6612, cent_loss:0.0021
# sv loss: 0.6666, sv eer: 0.1368
# epoch [87/100], loss:0.6608, ae_loss:0.6589, cent_loss:0.0020
# sv loss: 0.6586, sv eer: 0.1356
# epoch [88/100], loss:0.6593, ae_loss:0.6573, cent_loss:0.0020
# sv loss: 0.6552, sv eer: 0.1337
# epoch [89/100], loss:0.6586, ae_loss:0.6566, cent_loss:0.0019
# sv loss: 0.6569, sv eer: 0.1316
# epoch [90/100], loss:0.6565, ae_loss:0.6547, cent_loss:0.0018
# sv loss: 0.6524, sv eer: 0.1322
# epoch [91/100], loss:0.6571, ae_loss:0.6553, cent_loss:0.0018
# sv loss: 0.6544, sv eer: 0.1296
# epoch [92/100], loss:0.6567, ae_loss:0.6549, cent_loss:0.0017
# sv loss: 0.6534, sv eer: 0.1295
# epoch [93/100], loss:0.6557, ae_loss:0.6537, cent_loss:0.0020
# sv loss: 0.6533, sv eer: 0.1292
# epoch [94/100], loss:0.6493, ae_loss:0.6471, cent_loss:0.0022
# sv loss: 0.6504, sv eer: 0.1351
# epoch [95/100], loss:0.6485, ae_loss:0.6463, cent_loss:0.0022
# sv loss: 0.6445, sv eer: 0.1325
# epoch [96/100], loss:0.6432, ae_loss:0.6412, cent_loss:0.0020
# sv loss: 0.6444, sv eer: 0.1302
# epoch [97/100], loss:0.6403, ae_loss:0.6384, cent_loss:0.0019
# sv loss: 0.6407, sv eer: 0.1275
# epoch [98/100], loss:0.6394, ae_loss:0.6375, cent_loss:0.0019
# sv loss: 0.6378, sv eer: 0.1256
# epoch [99/100], loss:0.6421, ae_loss:0.6401, cent_loss:0.0019
# sv loss: 0.6372, sv eer: 0.1234
# epoch [100/100], loss:0.6373, ae_loss:0.6353, cent_loss:0.0020
# sv loss: 0.6379, sv eer: 0.1222
