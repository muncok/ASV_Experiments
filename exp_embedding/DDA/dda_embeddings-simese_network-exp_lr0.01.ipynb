# %% [markdown]
# # Siamese Network
# ------------------------------
#
# Constrastive loss: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
#
# Siamese Network for one shot learning: https://www.cs.cmu.edu/~rsalakhu/papers/oneshot1.pdf

# %% [markdown]
# ### Environment

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab
# %matplotlib inline

import pandas as pd
import pickle
import numpy as np
import sys
import os
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.append('../')
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ### Configuration

# %%
from sv_system.utils.parser import set_train_config
import easydict

# datasets
# voxc1_fbank_xvector
# gcommand_fbank_xvector

args = easydict.EasyDict(dict(dataset="voxc1_fbank_xvector",
                              input_frames=100, splice_frames=[50, 100], stride_frames=1, input_format='fbank',
                              cuda=True,
                              lrs=[0.1, 0.01], lr_schedule=[20], seed=1337,
                              no_eer=False,
                              batch_size=128,
                              arch="tdnn_conv", loss="softmax",
                              n_epochs=50
                             ))
config = set_train_config(args)

# %% [markdown]
# ### Dataset

# %%
import torch.utils.data as data

class embedDataset(data.Dataset):
    def __init__(self, embeds, labels):
        super().__init__()
        self.embeds = embeds
        self.labels = labels
        
    def __getitem__(self, index):
        
        return self.embeds[index], self.labels[index]
    
    def __len__(self):
        
        return self.embeds.shape[0]

# %%
def embedToDataset(embeds, key_df):
    labels = key_df.label.tolist()
    dataset = embedDataset(embeds, labels)
    
    return dataset, embeds.shape[1], len(key_df.label.unique())

# %%
trial = pd.read_pickle("../dataset/dataframes/voxc1/voxc_trial.pkl")

# %%
si_keys = pickle.load(open("../embeddings/voxc12/xvectors/xvectors_tdnn7b/train_feat/key.pkl", "rb"))
si_embeds = np.load("../embeddings/voxc12/xvectors/xvectors_tdnn7b/train_feat/feat.npy")

sv_keys = pickle.load(open("../embeddings/voxc12/xvectors/xvectors_tdnn7b/test_feat/key.pkl", "rb"))
sv_embeds = np.load("../embeddings/voxc12/xvectors/xvectors_tdnn7b/test_feat/feat.npy")

# %%
# voxc1_keys = embed_keys[embed_keys.origin == 'voxc1']

# %%
def key2df(keys):
    key_df = pd.DataFrame(keys, columns=['key'])
    key_df['spk'] = key_df.key.apply(lambda x: x.split("-")[0])
    key_df['label'] = key_df.groupby('spk').ngroup()
    key_df['origin'] = key_df.spk.apply(lambda x: 'voxc2' if x.startswith('id') else 'voxc1')
    
    return key_df

# %%
si_key_df = key2df(si_keys)
sv_key_df = key2df(sv_keys)

# %%
si_dataset, embed_dim, n_labels = embedToDataset(si_embeds, si_key_df)
sv_dataset, _, _ = embedToDataset(sv_embeds, sv_key_df)

# %% [markdown]
# ### Batch Sampler

# %%
import math
import random
import itertools

def index_dataset(dataset):
    return {c : [example_idx for example_idx, (_, class_label_ind) in \
                 enumerate(zip(dataset.embeds, dataset.labels)) if class_label_ind == c] 
            for c in set(dataset.labels)}

def sample_from_class(images_by_class, class_label_ind):
    return images_by_class[class_label_ind][random.randrange(len(images_by_class[class_label_ind]))]

def simple(batch_size, dataset, class2img = None, prob_other = 0.5):
    '''lazy sampling, not like in lifted_struct. they add to the pool all postiive combinations, 
    then compute the average number of positive pairs per image,
    then sample for every image the same number of negative pairs'''
    
    if class2img is not None:
        images_by_class = class2img
    else:
        images_by_class = index_dataset(dataset)
        
    for batch_idx in range(int(math.ceil(len(dataset) * 1.0 / batch_size))):
        example_indices = []
        for i in range(0, batch_size, 2):
            perm = random.sample(images_by_class.keys(), 2)
            example_indices += [sample_from_class(images_by_class, perm[0]), 
                                sample_from_class(images_by_class, perm[0 if i == 0 or random.random() > prob_other else 1])]
        yield example_indices[:batch_size]

# %%
si_key_df['num_id'] = range(len(si_key_df))
si_class2idx = si_key_df.groupby('label').apply(lambda x: x.num_id.values).to_dict()

# %% [markdown]
# ### Sampler

# %%
adapt_sampler = lambda batch, dataset, sampler, **kwargs: \
type('', (torch.utils.data.sampler.Sampler,), 
     dict(__len__ = dataset.__len__, __iter__ = \
          lambda _: itertools.chain.from_iterable(sampler(batch, dataset, **kwargs))))(dataset)

# %% [markdown]
# ### Model Define

# %%
import torch.nn as nn
import torch.nn.functional as F

class siamese_model(nn.Module):
    def __init__(self, in_dims, n_layers, n_labels):
        super().__init__()
        
        self.input_layer = nn.Sequential(
            nn.Linear(in_dims, 1*in_dims),
            nn.PReLU()
        )
        
        hidden_layer = [nn.Linear(1*in_dims, 1*in_dims),
            nn.BatchNorm1d(1*in_dims),
            nn.PReLU()] * n_layers
        
        self.hidden_layer = nn.Sequential(*hidden_layer)
    
        self.embedding_layer = nn.Sequential(
            nn.Linear(1*in_dims, 1),
        )
        
    def embed(self, x):
        x = self.input_layer(x)
        x = self.hidden_layer(x)
        
        return x
    
    def score(self, embed1, embed2):
        dist = embed1.sub(embed2).abs()
        dist = torch.clamp(dist, min=1e-16) # for numerical stability
        weighted_dist = self.embedding_layer(dist)
        
        return weighted_dist.squeeze(1)
        
    
    def forward(self, x1, x2):           
        embed1 = self.embed(x1)
        embed2 = self.embed(x2)
        
        p = self.score(embed1, embed2)
        
        return p

# %% [markdown]
# ### Train funcs

# %%
import torch.nn.functional as F

def embeds_utterance(config, val_dataloader, model):
    embeddings = []
    labels = []
    model.eval()

    with torch.no_grad():
        for batch in val_dataloader:
            X, y = batch
            if not config['no_cuda']:
                X = X.cuda()
                model = model.cuda()
                
            model_output = model.embed(X).cpu().detach()
            embeddings.append(model_output)
            labels.append(y.numpy())
        embeddings = torch.cat(embeddings)
        labels = np.hstack(labels)
    return embeddings, labels 

def sv_test(config, sv_loader, model, trial):
        embeddings, _ = embeds_utterance(config, sv_loader, model)
        trial_enroll = embeddings[trial.enrolment_id.tolist()]
        trial_test = embeddings[trial.test_id.tolist()]
        
        model = model.cpu()
        model.eval()
        score_vector = torch.sigmoid(model.score(trial_enroll, trial_test)).detach().numpy()
        label_vector = np.array(trial.label)
        fpr, tpr, thres = roc_curve(
                label_vector, score_vector, pos_label=1)
        eer = fpr[np.nanargmin(np.abs(fpr - (1 - tpr)))]

        return eer, label_vector, score_vector

# %%
def constrastive_loss(n1, n2, label, margin):
    dist_square = (n1 - n2).pow(2).sum(1)
    dist_square = torch.clamp(dist_square, min=1e-16)
    dist = dist_square.sqrt()

    loss = torch.mean(
        (1.0-label)*dist_square + (label)*torch.pow(torch.clamp(margin-dist, min=0.0), 2)
    )
    
    return loss

# %%
import torch

def siamese_train(model, loader, criterion, optimizer):
    model.train()
    loss_sum = 0
    n_corrects = 0
    total = 0
    for batch_idx, (X, y) in enumerate(loader):
        if not config['no_cuda']:
            model = model.cuda()
            X = X.cuda()
            y = y.cuda()

        optimizer.zero_grad()
        
        batch_size = X.size(0)
        x1 = X[0:batch_size:2]
        x2 = X[1:batch_size:2]
        embeds = model(x1, x2)

        y1 = y[0:batch_size:2]
        y2 = y[1:batch_size:2]
        
        label = y1.eq(y2).float() # equal or diff
        loss = criterion(embeds, label)
        loss.backward()
        optimizer.step()
                        
        loss_sum += loss.item()
        total += y.size(0)
#         if (batch_idx+1) % 1000 == 0:
#             print("Batch {}/{}\t Loss {:.6f}" \
#                   .format(batch_idx+1, len(loader), loss_sum / total))
    return loss_sum / total

# %%
from sv_system.train.si_train import val
from sklearn.metrics import roc_curve
from tensorboardX import SummaryWriter

def run_train(config, model, si_loader, sv_loader, criterion, optimizer, scheduler, writer):
    for epoch_idx in range(0, config['n_epochs']):
        print("-"*30)
        curr_lr = optimizer.state_dict()['param_groups'][0]['lr']
        print("curr_lr: {}".format(curr_lr))
#         step_scheduler.step()    

#         train code
        train_loss = siamese_train(model, si_loader, criterion, optimizer)
        print("epoch #{}, train loss: {}".format(epoch_idx, train_loss))
        writer.add_scalar("train/loss", train_loss, epoch_idx+1)

#         evaluate best_metric
        if not config['no_eer']:
            # eer validation code
            eer, label, score = sv_test(config, sv_loader, model, trial)
            print("epoch #{}, sv eer: {:.4f}".format(epoch_idx, eer))
            writer.add_scalar("sv_test/eer", eer, epoch_idx+1)
        
        scheduler.step(train_loss)
        
    return model

# %% [markdown]
# ### Training setting

# %%
from sv_system.train.train_utils import set_seed, find_optimizer
from torch.optim.lr_scheduler import ReduceLROnPlateau, MultiStepLR
from torch.utils.data.dataloader import DataLoader

def set_train_environment(init_lar, n_pairs, n_layers):
    batch_size = n_pairs * 2
    model = siamese_model(embed_dim, n_layers, n_labels) 

    optimizer = torch.optim.SGD(model.parameters(), lr=init_lr, momentum=0.9, weight_decay=5e-4)
    criterion = nn.BCEWithLogitsLoss()
    scheduler = ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=5)
    # step_scheduler = MultiStepLR(optimizer, [30], 0.1)

    si_loader = DataLoader(si_dataset, 
                           sampler = adapt_sampler(
                               batch_size, si_dataset, simple, class2img=si_class2idx
                           ), 
                           num_workers = 0, batch_size = batch_size, 
                           drop_last = True, pin_memory = True)
    sv_loader = DataLoader(sv_dataset, batch_size=128, num_workers=0, shuffle=False)

    exp_name = "xvector_siamese_lr{}_batch{}_ls{}".format(init_lr, batch_size, n_layers)
    writer = SummaryWriter(f"logs/{exp_name}.tf.log")
    
    print("="*60)
    print(f"run experiment: {exp_name}")
    
    
    return  model, si_loader, sv_loader, criterion, optimizer, scheduler, writer

# %% [markdown]
# ### Run training

# %%
import itertools

config['n_epochs'] = 30

for idx, (init_lr, n_pairs, n_layers) in enumerate(itertools.product([0.01], [32, 64, 128], [2,3,4])):
    if idx == 0:
        continue
    model = run_train(config, *set_train_environment(init_lr, n_pairs, n_layers))
#     torch.save(model.state_dict(), open(f"saved_models/{exp_name}.pt", "wb"))
# Out:
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch64_ls3
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.0026993454041365343
# epoch #0, sv eer: 0.0974869555957832
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.0020538887026893167
# epoch #1, sv eer: 0.09711425833244595
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.0019771061050798
# epoch #2, sv eer: 0.08870194867426259
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.0019343708449213088
# epoch #3, sv eer: 0.09008625279522947
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.0019170465660943027
# epoch #4, sv eer: 0.0943456500905122
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.0019075934282174404
# epoch #5, sv eer: 0.09120434458524118
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.0019018959817990958
# epoch #6, sv eer: 0.09274837610478118
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.0018823220791968722
# epoch #7, sv eer: 0.09541049941433287
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.0018874511582138407
# epoch #8, sv eer: 0.09115110211905016
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.0019031938274638163
# epoch #9, sv eer: 0.09104461718666809
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.0018895454628002869
# epoch #10, sv eer: 0.09083164732190395
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.0018904157660067666
# epoch #11, sv eer: 0.09509104461718666
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.0018748691498738771
# epoch #12, sv eer: 0.09333404323288255
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.0018800423113738691
# epoch #13, sv eer: 0.09290810350335428
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.0018735239638979753
# epoch #14, sv eer: 0.0951442870833777
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.0018689703553770383
# epoch #15, sv eer: 0.0948248322862315
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.0018822406843068806
# epoch #16, sv eer: 0.0928016185709722
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.0018745688893938306
# epoch #17, sv eer: 0.09253540624001703
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.001877384959382232
# epoch #18, sv eer: 0.0941859226919391
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.0018867344866544365
# epoch #19, sv eer: 0.09269513363859014
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.0018835246608364055
# epoch #20, sv eer: 0.08641252262804813
# ------------------------------
# curr_lr: 0.01
# epoch #21, train loss: 0.001866641897141692
# epoch #21, sv eer: 0.09274837610478118
# ------------------------------
# curr_lr: 0.01
# epoch #22, train loss: 0.0018661419961026528
# epoch #22, sv eer: 0.0898200404642743
# ------------------------------
# curr_lr: 0.01
# epoch #23, train loss: 0.0018728600615195482
# epoch #23, sv eer: 0.09471834735384943
# ------------------------------
# curr_lr: 0.01
# epoch #24, train loss: 0.0018818459510367925
# epoch #24, sv eer: 0.08992652539665637
# ------------------------------
# curr_lr: 0.01
# epoch #25, train loss: 0.0018710156175207793
# epoch #25, sv eer: 0.09242892130763497
# ------------------------------
# curr_lr: 0.01
# epoch #26, train loss: 0.0018825948979108232
# epoch #26, sv eer: 0.0953040144819508
# ------------------------------
# curr_lr: 0.01
# epoch #27, train loss: 0.0018719735746942612
# epoch #27, sv eer: 0.0926418911723991
# ------------------------------
# curr_lr: 0.01
# epoch #28, train loss: 0.0018713220186072088
# epoch #28, sv eer: 0.0941859226919391
# ------------------------------
# curr_lr: 0.001
# epoch #29, train loss: 0.0016441347750241022
# epoch #29, sv eer: 0.08673197742519434
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch64_ls4
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.002770811218612776
# epoch #0, sv eer: 0.09951016931104249
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.002117362794913348
# epoch #1, sv eer: 0.0953040144819508
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.002041470483877045
# epoch #2, sv eer: 0.09163028431476947
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.0020136599221136186
# epoch #3, sv eer: 0.09445213502289426
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.0019873357842114486
# epoch #4, sv eer: 0.09615589394100735
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.0019770959204072993
# epoch #5, sv eer: 0.0890214034714088
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.001966014394102345
# epoch #6, sv eer: 0.09546374188052391
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.001966011681821909
# epoch #7, sv eer: 0.0929613459695453
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.0019565822224957485
# epoch #8, sv eer: 0.09029922265999361
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.0019602572623464163
# epoch #9, sv eer: 0.09572995421147908
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.001959521975446128
# epoch #10, sv eer: 0.09189649664572463
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.0019509621795795172
# epoch #11, sv eer: 0.0918432541795336
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.0019505148417658128
# epoch #12, sv eer: 0.09391971036098393
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.0019538313596642745
# epoch #13, sv eer: 0.09450537748908529
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.0019466042963984967
# epoch #14, sv eer: 0.0920029815781067
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.0019537747049243478
# epoch #15, sv eer: 0.09333404323288255
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.001959973080974443
# epoch #16, sv eer: 0.0920029815781067
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.0019490566941539826
# epoch #17, sv eer: 0.09839207752103077
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.0019571861665826453
# epoch #18, sv eer: 0.09769992546054733
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.0019499948607169212
# epoch #19, sv eer: 0.09333404323288255
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.001955884844251826
# epoch #20, sv eer: 0.09141731445000532
# ------------------------------
# curr_lr: 0.001
# epoch #21, train loss: 0.0017232460477019076
# epoch #21, sv eer: 0.08593334043232882
# ------------------------------
# curr_lr: 0.001
# epoch #22, train loss: 0.0016023859202080341
# epoch #22, sv eer: 0.08524118837184538
# ------------------------------
# curr_lr: 0.001
# epoch #23, train loss: 0.0015462209191943817
# epoch #23, sv eer: 0.08662549249281226
# ------------------------------
# curr_lr: 0.001
# epoch #24, train loss: 0.0014897292207079157
# epoch #24, sv eer: 0.0863592801618571
# ------------------------------
# curr_lr: 0.001
# epoch #25, train loss: 0.0014715619607851259
# epoch #25, sv eer: 0.08566712810137365
# ------------------------------
# curr_lr: 0.001
# epoch #26, train loss: 0.001455576252720412
# epoch #26, sv eer: 0.08731764455329571
# ------------------------------
# curr_lr: 0.001
# epoch #27, train loss: 0.0014377199151945162
# epoch #27, sv eer: 0.08763709935044191
# ------------------------------
# curr_lr: 0.001
# epoch #28, train loss: 0.0014382293007955444
# epoch #28, sv eer: 0.08774358428282399
# ------------------------------
# curr_lr: 0.001
# epoch #29, train loss: 0.001439958688459073
# epoch #29, sv eer: 0.08614631029709297
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch128_ls2
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.0013278738879934624
# epoch #0, sv eer: 0.09258864870620807
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.0009504524714400701
# epoch #1, sv eer: 0.09445213502289426
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.0008821306923663996
# epoch #2, sv eer: 0.09147055691619636
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.0008548789375144004
# epoch #3, sv eer: 0.09061867745713982
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.0008428086812014436
# epoch #4, sv eer: 0.09290810350335428
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.0008335425234501221
# epoch #5, sv eer: 0.0923224363752529
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.0008199937187507562
# epoch #6, sv eer: 0.0898200404642743
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.0008165047074638831
# epoch #7, sv eer: 0.09045895005856672
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.0008123440798793715
# epoch #8, sv eer: 0.08609306783090193
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.000810972618996301
# epoch #9, sv eer: 0.0866787349590033
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.0008086283049470477
# epoch #10, sv eer: 0.08939410073474603
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.000805174500168731
# epoch #11, sv eer: 0.08758385688425088
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.0007977388535972913
# epoch #12, sv eer: 0.0896603130657012
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.0008030935926262554
# epoch #13, sv eer: 0.08566712810137365
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.000788979877226469
# epoch #14, sv eer: 0.0895005856671281
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.0007905087848499563
# epoch #15, sv eer: 0.09029922265999361
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.0007890629360751731
# epoch #16, sv eer: 0.0895005856671281
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.0007862669023336844
# epoch #17, sv eer: 0.08864870620807155
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.0007810527692346662
# epoch #18, sv eer: 0.08508146097327228
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.0007884798990265104
# epoch #19, sv eer: 0.08774358428282399
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.0007829605676193524
# epoch #20, sv eer: 0.0899797678628474
# ------------------------------
# curr_lr: 0.01
# epoch #21, train loss: 0.000781095032593903
# epoch #21, sv eer: 0.09179001171334256
# ------------------------------
# curr_lr: 0.01
# epoch #22, train loss: 0.0007770330606577036
# epoch #22, sv eer: 0.09035246512618464
# ------------------------------
# curr_lr: 0.01
# epoch #23, train loss: 0.0007793118400254963
# epoch #23, sv eer: 0.08769034181663295
# ------------------------------
# curr_lr: 0.01
# epoch #24, train loss: 0.0007797442889255136
# epoch #24, sv eer: 0.08566712810137365
# ------------------------------
# curr_lr: 0.01
# epoch #25, train loss: 0.0007811111649083657
# epoch #25, sv eer: 0.08928761580236397
# ------------------------------
# curr_lr: 0.01
# epoch #26, train loss: 0.000775932193902484
# epoch #26, sv eer: 0.08934085826855499
# ------------------------------
# curr_lr: 0.01
# epoch #27, train loss: 0.0007844604699673432
# epoch #27, sv eer: 0.08939410073474603
# ------------------------------
# curr_lr: 0.01
# epoch #28, train loss: 0.0007795718183066394
# epoch #28, sv eer: 0.09008625279522947
# ------------------------------
# curr_lr: 0.01
# epoch #29, train loss: 0.0007803145759447477
# epoch #29, sv eer: 0.09120434458524118
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch128_ls3
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.001380991508408178
# epoch #0, sv eer: 0.09439889255670322
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.000979413582073706
# epoch #1, sv eer: 0.09785965285912043
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.0009223719017418243
# epoch #2, sv eer: 0.09823235012245768
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.0008882613324216462
# epoch #3, sv eer: 0.09157704184857843
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.0008702277418097457
# epoch #4, sv eer: 0.09093813225428601
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.0008523963215714344
# epoch #5, sv eer: 0.08976679799808328
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.0008385481515110522
# epoch #6, sv eer: 0.08859546374188053
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.0008367426634269472
# epoch #7, sv eer: 0.09274837610478118
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.0008330441343090997
# epoch #8, sv eer: 0.09045895005856672
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.0008205767323894991
# epoch #9, sv eer: 0.09163028431476947
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.000823640487213558
# epoch #10, sv eer: 0.08753061441805984
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.0008228879608251813
# epoch #11, sv eer: 0.08854222127568949
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.0008164479980086707
# epoch #12, sv eer: 0.09056543499094878
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.000811346072285648
# epoch #13, sv eer: 0.09173676924715153
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.0008098627945705329
# epoch #14, sv eer: 0.09093813225428601
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.0008092081387138147
# epoch #15, sv eer: 0.0865190075604302
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.0008030332822894131
# epoch #16, sv eer: 0.09104461718666809
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.0008006364510007127
# epoch #17, sv eer: 0.08992652539665637
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.0008015560542385165
# epoch #18, sv eer: 0.09104461718666809
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.0008033279501770031
# epoch #19, sv eer: 0.08939410073474603
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.0007998785530615347
# epoch #20, sv eer: 0.08960707059951017
# ------------------------------
# curr_lr: 0.01
# epoch #21, train loss: 0.0007976672059726525
# epoch #21, sv eer: 0.08795655414758811
# ------------------------------
# curr_lr: 0.01
# epoch #22, train loss: 0.0007987560798646299
# epoch #22, sv eer: 0.08960707059951017
# ------------------------------
# curr_lr: 0.01
# epoch #23, train loss: 0.0007950688974641615
# epoch #23, sv eer: 0.08806303907997018
# ------------------------------
# curr_lr: 0.01
# epoch #24, train loss: 0.000791506499248834
# epoch #24, sv eer: 0.09237567884144393
# ------------------------------
# curr_lr: 0.01
# epoch #25, train loss: 0.0007940526843863145
# epoch #25, sv eer: 0.08689170482376744
# ------------------------------
# curr_lr: 0.01
# epoch #26, train loss: 0.0007952191195490267
# epoch #26, sv eer: 0.0890214034714088
# ------------------------------
# curr_lr: 0.01
# epoch #27, train loss: 0.0007977215134097078
# epoch #27, sv eer: 0.08928761580236397
# ------------------------------
# curr_lr: 0.01
# epoch #28, train loss: 0.0007912683065087494
# epoch #28, sv eer: 0.09301458843573635
# ------------------------------
# curr_lr: 0.01
# epoch #29, train loss: 0.0007914635292876708
# epoch #29, sv eer: 0.08646576509423917
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch128_ls4
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.0014405941315551003
# epoch #0, sv eer: 0.10009583643914387
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.001006834194640851
# epoch #1, sv eer: 0.09631562133958045
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.0009270443468682891
# epoch #2, sv eer: 0.09759344052816527
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.0009096921850971034
# epoch #3, sv eer: 0.09775316792673837
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.000877832962477786
# epoch #4, sv eer: 0.09136407198381429
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.0008623550688058888
# epoch #5, sv eer: 0.09487807475242253
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.0008558854187670993
# epoch #6, sv eer: 0.09328080076669151
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.0008462716665483226
# epoch #7, sv eer: 0.09093813225428601
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.0008429467320381659
# epoch #8, sv eer: 0.09370674049621978
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.0008342503801757262
# epoch #9, sv eer: 0.08619955276328399
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.0008315368023699729
# epoch #10, sv eer: 0.08928761580236397
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.0008357782687160503
# epoch #11, sv eer: 0.08944734320093707
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.0008286988704727439
# epoch #12, sv eer: 0.09242892130763497
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.0008254749591768867
# epoch #13, sv eer: 0.08923437333617293
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.0008222968385559866
# epoch #14, sv eer: 0.0953040144819508
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.000824400102999038
# epoch #15, sv eer: 0.08960707059951017
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.0008130099398169954
# epoch #16, sv eer: 0.09147055691619636
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.0008100558046403412
# epoch #17, sv eer: 0.09003301032903845
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.0008086020156538407
# epoch #18, sv eer: 0.08699818975614951
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.0008137675797060983
# epoch #19, sv eer: 0.08827600894473432
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.0008153730752142539
# epoch #20, sv eer: 0.0920029815781067
# ------------------------------
# curr_lr: 0.01
# epoch #21, train loss: 0.0008120534697860524
# epoch #21, sv eer: 0.08934085826855499
# ------------------------------
# curr_lr: 0.01
# epoch #22, train loss: 0.0008108295035987807
# epoch #22, sv eer: 0.09131082951762326
# ------------------------------
# curr_lr: 0.01
# epoch #23, train loss: 0.0008175663963645671
# epoch #23, sv eer: 0.09727398573101906
# ------------------------------
# curr_lr: 0.01
# epoch #24, train loss: 0.0008082790094744349
# epoch #24, sv eer: 0.09338728569907358
# ------------------------------
# curr_lr: 0.01
# epoch #25, train loss: 0.0008086270763644228
# epoch #25, sv eer: 0.09115110211905016
# ------------------------------
# curr_lr: 0.01
# epoch #26, train loss: 0.0008071062868826239
# epoch #26, sv eer: 0.09301458843573635
# ------------------------------
# curr_lr: 0.01
# epoch #27, train loss: 0.0008083331586761803
# epoch #27, sv eer: 0.09226919390906187
# ------------------------------
# curr_lr: 0.01
# epoch #28, train loss: 0.0008120640274003112
# epoch #28, sv eer: 0.09163028431476947
# ------------------------------
# curr_lr: 0.01
# epoch #29, train loss: 0.0008137955282340508
# epoch #29, sv eer: 0.0921627089766798
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch256_ls2
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.0007319808825159927
# epoch #0, sv eer: 0.10163986795868385
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.0004909800849804787
# epoch #1, sv eer: 0.09578319667767012
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.0004356609017530807
# epoch #2, sv eer: 0.09370674049621978
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.00041771482547720847
# epoch #3, sv eer: 0.08827600894473432
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.0004031908764928031
# epoch #4, sv eer: 0.09466510488765839
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.00039194702713905215
# epoch #5, sv eer: 0.09077840485571291
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.0003833523618541112
# epoch #6, sv eer: 0.0899797678628474
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.0003791331915209468
# epoch #7, sv eer: 0.09024598019380257
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.0003742189566979935
# epoch #8, sv eer: 0.09131082951762326
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.0003710120754312483
# epoch #9, sv eer: 0.08987328293046534
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.00036852582733024134
# epoch #10, sv eer: 0.08896816100521776
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.000366117510226516
# epoch #11, sv eer: 0.09003301032903845
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.00036264308741692277
# epoch #12, sv eer: 0.08880843360664466
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.00035794167216264837
# epoch #13, sv eer: 0.08987328293046534
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.0003587849406097509
# epoch #14, sv eer: 0.08561388563518262
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.000353298253003687
# epoch #15, sv eer: 0.09024598019380257
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.00035593269331111733
# epoch #16, sv eer: 0.08705143222234053
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.0003553178424031622
# epoch #17, sv eer: 0.08603982536471089
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.0003534891657298664
# epoch #18, sv eer: 0.08619955276328399
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.0003497656226031695
# epoch #19, sv eer: 0.08742412948567778
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.00034972745013287486
# epoch #20, sv eer: 0.09045895005856672
# ------------------------------
# curr_lr: 0.01
# epoch #21, train loss: 0.0003516681063732455
# epoch #21, sv eer: 0.08944734320093707
# ------------------------------
# curr_lr: 0.01
# epoch #22, train loss: 0.0003502796546025071
# epoch #22, sv eer: 0.09029922265999361
# ------------------------------
# curr_lr: 0.01
# epoch #23, train loss: 0.0003483200222491179
# epoch #23, sv eer: 0.08896816100521776
# ------------------------------
# curr_lr: 0.01
# epoch #24, train loss: 0.0003486038461296758
# epoch #24, sv eer: 0.08614631029709297
# ------------------------------
# curr_lr: 0.01
# epoch #25, train loss: 0.0003473196231881049
# epoch #25, sv eer: 0.08753061441805984
# ------------------------------
# curr_lr: 0.01
# epoch #26, train loss: 0.00034497010301183143
# epoch #26, sv eer: 0.08630603769566607
# ------------------------------
# curr_lr: 0.01
# epoch #27, train loss: 0.0003457833360069905
# epoch #27, sv eer: 0.08662549249281226
# ------------------------------
# curr_lr: 0.01
# epoch #28, train loss: 0.0003439486957430342
# epoch #28, sv eer: 0.08864870620807155
# ------------------------------
# curr_lr: 0.01
# epoch #29, train loss: 0.0003461884488367974
# epoch #29, sv eer: 0.08912788840379086
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch256_ls3
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.0007493782198389727
# epoch #0, sv eer: 0.09636886380577149
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.0005079814854302194
# epoch #1, sv eer: 0.09525077201575977
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.00045129576603635186
# epoch #2, sv eer: 0.09349377063145566
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.0004237721436531031
# epoch #3, sv eer: 0.09338728569907358
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.00041365484038194297
# epoch #4, sv eer: 0.08896816100521776
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.00040255390481315533
# epoch #5, sv eer: 0.09290810350335428
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.0003966622508135867
# epoch #6, sv eer: 0.09274837610478118
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.0003878306265080997
# epoch #7, sv eer: 0.09194973911191566
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.0003894531249755971
# epoch #8, sv eer: 0.09147055691619636
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.000382903369696753
# epoch #9, sv eer: 0.09019273772761155
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.00037995917135956914
# epoch #10, sv eer: 0.09237567884144393
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.00037793737275189745
# epoch #11, sv eer: 0.0895005856671281
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.0003743669299637075
# epoch #12, sv eer: 0.09173676924715153
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.0003767427718644203
# epoch #13, sv eer: 0.09024598019380257
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.00037356848805573093
# epoch #14, sv eer: 0.09125758705143222
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.00037010355611898207
# epoch #15, sv eer: 0.09269513363859014
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.0003668104283715074
# epoch #16, sv eer: 0.08907464593759983
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.0003678930598709598
# epoch #17, sv eer: 0.0895005856671281
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.0003653181392531156
# epoch #18, sv eer: 0.09040570759237568
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.00036233881684587076
# epoch #19, sv eer: 0.0899797678628474
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.00036546562262087547
# epoch #20, sv eer: 0.08843573634330743
# ------------------------------
# curr_lr: 0.01
# epoch #21, train loss: 0.00036159732776295297
# epoch #21, sv eer: 0.09205622404429774
# ------------------------------
# curr_lr: 0.01
# epoch #22, train loss: 0.00036030145767548463
# epoch #22, sv eer: 0.08955382813331914
# ------------------------------
# curr_lr: 0.01
# epoch #23, train loss: 0.0003639636726594784
# epoch #23, sv eer: 0.08928761580236397
# ------------------------------
# curr_lr: 0.01
# epoch #24, train loss: 0.0003580597923390375
# epoch #24, sv eer: 0.09386646789479289
# ------------------------------
# curr_lr: 0.01
# epoch #25, train loss: 0.00035974481035303186
# epoch #25, sv eer: 0.08774358428282399
# ------------------------------
# curr_lr: 0.01
# epoch #26, train loss: 0.00036013524690705945
# epoch #26, sv eer: 0.09061867745713982
# ------------------------------
# curr_lr: 0.01
# epoch #27, train loss: 0.0003552081741876471
# epoch #27, sv eer: 0.0896603130657012
# ------------------------------
# curr_lr: 0.01
# epoch #28, train loss: 0.00035619925441211537
# epoch #28, sv eer: 0.09152379938238739
# ------------------------------
# curr_lr: 0.01
# epoch #29, train loss: 0.0003592815579092835
# epoch #29, sv eer: 0.0863592801618571
# ============================================================
# run experiment: xvector_siamese_lr0.01_batch256_ls4
# ------------------------------
# curr_lr: 0.01
# epoch #0, train loss: 0.0007783111056930223
# epoch #0, sv eer: 0.10808220636779896
# ------------------------------
# curr_lr: 0.01
# epoch #1, train loss: 0.0005312843593702985
# epoch #1, sv eer: 0.09801938025769354
# ------------------------------
# curr_lr: 0.01
# epoch #2, train loss: 0.0004688054917696098
# epoch #2, sv eer: 0.09754019806197423
# ------------------------------
# curr_lr: 0.01
# epoch #3, train loss: 0.00044031903940149845
# epoch #3, sv eer: 0.09722074326482803
# ------------------------------
# curr_lr: 0.01
# epoch #4, train loss: 0.0004288431000557517
# epoch #4, sv eer: 0.09599616654243424
# ------------------------------
# curr_lr: 0.01
# epoch #5, train loss: 0.00041594836530896214
# epoch #5, sv eer: 0.09562346927909701
# ------------------------------
# curr_lr: 0.01
# epoch #6, train loss: 0.0004079922757767405
# epoch #6, sv eer: 0.09445213502289426
# ------------------------------
# curr_lr: 0.01
# epoch #7, train loss: 0.00039965258279016505
# epoch #7, sv eer: 0.0923224363752529
# ------------------------------
# curr_lr: 0.01
# epoch #8, train loss: 0.00039147142002887215
# epoch #8, sv eer: 0.09572995421147908
# ------------------------------
# curr_lr: 0.01
# epoch #9, train loss: 0.00038903894344762804
# epoch #9, sv eer: 0.09466510488765839
# ------------------------------
# curr_lr: 0.01
# epoch #10, train loss: 0.000388517741226817
# epoch #10, sv eer: 0.09365349803002875
# ------------------------------
# curr_lr: 0.01
# epoch #11, train loss: 0.0003812657105423816
# epoch #11, sv eer: 0.09487807475242253
# ------------------------------
# curr_lr: 0.01
# epoch #12, train loss: 0.0003799549683552648
# epoch #12, sv eer: 0.09679480353529976
# ------------------------------
# curr_lr: 0.01
# epoch #13, train loss: 0.0003775728416835837
# epoch #13, sv eer: 0.0918432541795336
# ------------------------------
# curr_lr: 0.01
# epoch #14, train loss: 0.00037595053480561066
# epoch #14, sv eer: 0.09360025556383772
# ------------------------------
# curr_lr: 0.01
# epoch #15, train loss: 0.0003719384052058381
# epoch #15, sv eer: 0.09115110211905016
# ------------------------------
# curr_lr: 0.01
# epoch #16, train loss: 0.00037158488245871764
# epoch #16, sv eer: 0.09370674049621978
# ------------------------------
# curr_lr: 0.01
# epoch #17, train loss: 0.00036813990108401444
# epoch #17, sv eer: 0.09205622404429774
# ------------------------------
# curr_lr: 0.01
# epoch #18, train loss: 0.0003692385551826128
# epoch #18, sv eer: 0.08800979661377915
# ------------------------------
# curr_lr: 0.01
# epoch #19, train loss: 0.00036954292178172424
# epoch #19, sv eer: 0.09083164732190395
# ------------------------------
# curr_lr: 0.01
# epoch #20, train loss: 0.00036706082720121925
# epoch #20, sv eer: 0.09365349803002875
# ------------------------------
# curr_lr: 0.01
# epoch #21, train loss: 0.00036371411341549277
# epoch #21, sv eer: 0.09333404323288255
# ------------------------------
# curr_lr: 0.01
# epoch #22, train loss: 0.00036870672200763977
# epoch #22, sv eer: 0.09179001171334256
# ------------------------------
# curr_lr: 0.01
# epoch #23, train loss: 0.0003655103638446596
# epoch #23, sv eer: 0.08864870620807155
# ------------------------------
# curr_lr: 0.01
# epoch #24, train loss: 0.0003647042611640232
# epoch #24, sv eer: 0.09173676924715153
# ------------------------------
# curr_lr: 0.01
# epoch #25, train loss: 0.00036467601851532645
# epoch #25, sv eer: 0.09189649664572463
# ------------------------------
# curr_lr: 0.01
# epoch #26, train loss: 0.00036282271921991854
# epoch #26, sv eer: 0.09029922265999361
# ------------------------------
# curr_lr: 0.01
# epoch #27, train loss: 0.0003624134916261133
# epoch #27, sv eer: 0.09312107336811841
# ------------------------------
# curr_lr: 0.01
# epoch #28, train loss: 0.00035993455564670867
# epoch #28, sv eer: 0.09019273772761155
# ------------------------------
# curr_lr: 0.01
# epoch #29, train loss: 0.0003584712858891342
# epoch #29, sv eer: 0.08896816100521776
