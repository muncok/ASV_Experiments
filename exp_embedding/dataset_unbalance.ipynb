# %%
import pandas as pd
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# voxceleb
voxc_df = pd.read_pickle("../dataset/dataframes/voxc/voxc_dataframe.pkl")

# %%
plt.figure(figsize=(10,10))
plt.xlabel("# of uttrs")
plt.ylabel("speaker ID")
voxc_df.spk.value_counts().hist(bins=20)

# %%
si_m_df = pd.read_pickle("../dataset/dataframes/voxc/si_m_voxc_dataframe.pkl")
si_f_df = pd.read_pickle("../dataset/dataframes/voxc/si_f_voxc_dataframe.pkl")

# %%
plt.figure(figsize=(10,10))
plt.xlabel("# of uttrs")
plt.ylabel("speaker ID")
si_m_df.spk.value_counts().hist(bins=20)

# %%
plt.figure(figsize=(10,10))
plt.xlabel("# of uttrs")
plt.ylabel("speaker ID")
si_f_df.spk.value_counts().hist(bins=20)
