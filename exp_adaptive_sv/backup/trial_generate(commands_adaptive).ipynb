# %% [markdown]
# ### Dataframe style looks better

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
import os
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_dir = 'dataset/speech_commands' # to concatenate audios
data_df = pd.read_pickle('dataset/dataframes/Command_Dataframe.pkl')

# %%
all_spks = list(data_df.spk.unique())
all_words = list(data_df.sent.unique())

# %%
data_df['file'] = data_df.apply(lambda x: os.path.join(x.sent, x.file), axis=1)

# %%
data_df
# Out:
#                      spk   sent                         file    set  label
# rightaba191270  aba19127  right  right/aba19127_nohash_0.wav  train    471
# right218321443  21832144  right  right/21832144_nohash_3.wav  train     81
# right3cdecb0b0  3cdecb0b  right  right/3cdecb0b_nohash_0.wav  train    276
# rightef2578c01  ef2578c0  right  right/ef2578c0_nohash_1.wav  train    911
# rightd0faf7e40  d0faf7e4  right  right/d0faf7e4_nohash_0.wav   test    644
# right93ec8b840  93ec8b84  right  right/93ec8b84_nohash_0.wav  train   1689
# rightf88f97a70  f88f97a7  right  right/f88f97a7_nohash_0.wav  train   1106
# right106a61831  106a6183  right  right/106a6183_nohash_1.wav  train   1341
# righte8d562ca2  e8d562ca  right  right/e8d562ca_nohash_2.wav  train    532
# right2296b1af0  2296b1af  right  right/2296b1af_nohash_0.wav    val   1238
# right87014d400  87014d40  right  right/87014d40_nohash_0.wav  train   1723
# rightcc2f1a850  cc2f1a85  right  right/cc2f1a85_nohash_0.wav  train   1328
# rightdea820ce0  dea820ce  right  right/dea820ce_nohash_0.wav  train    882
# righta1533da40  a1533da4  right  right/a1533da4_nohash_0.wav   test   1463
# rightdc7ec25b0  dc7ec25b  right  right/dc7ec25b_nohash_0.wav  train    425
# right3903b5581  3903b558  right  right/3903b558_nohash_1.wav    val   1068
# rightba59cab30  ba59cab3  right  right/ba59cab3_nohash_0.wav  train   1526
# right190821dc1  190821dc  right  right/190821dc_nohash_1.wav  train    579
# righteee9b9e24  eee9b9e2  right  right/eee9b9e2_nohash_4.wav    val    343
# rightc93d5e220  c93d5e22  right  right/c93d5e22_nohash_0.wav  train    988
# right9d7036f90  9d7036f9  right  right/9d7036f9_nohash_0.wav  train    801
# rightdbb40d243  dbb40d24  right  right/dbb40d24_nohash_3.wav    val   1496
# right0ac15fe91  0ac15fe9  right  right/0ac15fe9_nohash_1.wav  train   1008
# right8dd788d80  8dd788d8  right  right/8dd788d8_nohash_0.wav  train    460
# right58df33b50  58df33b5  right  right/58df33b5_nohash_0.wav  train    880
# right21e8c4170  21e8c417  right  right/21e8c417_nohash_0.wav  train    947
# right8781f4c10  8781f4c1  right  right/8781f4c1_nohash_0.wav  train    931
# righta84dee7b1  a84dee7b  right  right/a84dee7b_nohash_1.wav  train    924
# right9a69672b4  9a69672b  right  right/9a69672b_nohash_4.wav   test   1416
# right3cfc6b3a0  3cfc6b3a  right  right/3cfc6b3a_nohash_0.wav  train     44
# ...                  ...    ...                          ...    ...    ...
# nine2a0b413e0   2a0b413e   nine   nine/2a0b413e_nohash_0.wav  train    939
# nine7ea032f30   7ea032f3   nine   nine/7ea032f3_nohash_0.wav  train   1673
# nine6736bc641   6736bc64   nine   nine/6736bc64_nohash_1.wav   test     22
# ninec22d3f181   c22d3f18   nine   nine/c22d3f18_nohash_1.wav   test    843
# nine8f811bbc0   8f811bbc   nine   nine/8f811bbc_nohash_0.wav  train   1818
# nine2903efb30   2903efb3   nine   nine/2903efb3_nohash_0.wav  train   1168
# ninec0fb68122   c0fb6812   nine   nine/c0fb6812_nohash_2.wav  train   1595
# nine617de2214   617de221   nine   nine/617de221_nohash_4.wav  train    585
# ninea8ee11c73   a8ee11c7   nine   nine/a8ee11c7_nohash_3.wav  train   1045
# nine56eb74ae4   56eb74ae   nine   nine/56eb74ae_nohash_4.wav    val   1677
# nine8830e17f2   8830e17f   nine   nine/8830e17f_nohash_2.wav  train    761
# nine71bf8f483   71bf8f48   nine   nine/71bf8f48_nohash_3.wav  train    540
# nine611d2b502   611d2b50   nine   nine/611d2b50_nohash_2.wav  train   1782
# ninec6ee87a71   c6ee87a7   nine   nine/c6ee87a7_nohash_1.wav    val    354
# nine43b85b640   43b85b64   nine   nine/43b85b64_nohash_0.wav  train    340
# nine073636071   07363607   nine   nine/07363607_nohash_1.wav  train    787
# nine7c1d85330   7c1d8533   nine   nine/7c1d8533_nohash_0.wav    val    176
# nine5fb88f4c0   5fb88f4c   nine   nine/5fb88f4c_nohash_0.wav  train   1216
# nine238c112c1   238c112c   nine   nine/238c112c_nohash_1.wav  train    235
# ninedcc012ec0   dcc012ec   nine   nine/dcc012ec_nohash_0.wav  train   1523
# nine3bfd30e60   3bfd30e6   nine   nine/3bfd30e6_nohash_0.wav  train    109
# nineab7b5acd0   ab7b5acd   nine   nine/ab7b5acd_nohash_0.wav    val   1571
# ninecc6ee39b4   cc6ee39b   nine   nine/cc6ee39b_nohash_4.wav  train   1470
# nine735845ab3   735845ab   nine   nine/735845ab_nohash_3.wav  train   1275
# nined2f4f4310   d2f4f431   nine   nine/d2f4f431_nohash_0.wav  train   1575
# nine8f0d3c270   8f0d3c27   nine   nine/8f0d3c27_nohash_0.wav  train    811
# nine2da58b323   2da58b32   nine   nine/2da58b32_nohash_3.wav  train   1098
# nine7cfb16180   7cfb1618   nine   nine/7cfb1618_nohash_0.wav  train   1363
# nineda5dadb91   da5dadb9   nine   nine/da5dadb9_nohash_1.wav  train    561
# nineb49caed31   b49caed3   nine   nine/b49caed3_nohash_1.wav   test     64
#
# [64721 rows x 5 columns]

# %% [markdown]
# ### SV DataFrame

# %% [markdown]
# ## Manifest For Trial

# %%
spk_counts = data_df.spk.value_counts()

# %% [markdown]
# audio를 30개 이상 가진 스피커를 enroll speaker로 둔다.

# %%
sv_candidate = random.choice(spk_counts[spk_counts == 30].index, size=500, replace=False)

# %%
sv_val_spks = sv_candidate[:250]
sv_test_spks = sv_candidate[250:]

# %%
sv_val_df = data_df[data_df.spk.isin(sv_val_spks)]
sv_test_df = data_df[data_df.spk.isin(sv_test_spks)]

# %%
print("number of sv_val spks: {}".format(len(sv_val_df)))
print("number of sv_test spks: {}".format(len(sv_test_df)))
# Out:
# number of sv_val spks: 7500
# number of sv_test spks: 7500

# %% [markdown]
# trial이 저장될 폴더

# %%
dir_name = "trials/commands/validation/"
if not os.path.isdir(dir_name):
    os.makedirs(dir_name)

# %%
sv_val_df.to_pickle("{}/sv_val.pkl".format(dir_name))
sv_test_df.to_pickle("{}/sv_test.pkl".format(dir_name))

# %% [markdown]
# ### SI train Dataframe

# %%
si_df = data_df[~data_df.spk.isin(sv_candidate)]

# %%
si_df.to_pickle("{}/si_train.pkl".format(dir_name))

# %%
print("number of si spks: {}".format(len(si_df)))
# Out:
# number of si spks: 49721

# %% [markdown]
# ## For Human Performance

# %% [markdown]
# enrollment speakers: 3
# enrollment audios: 3
# pos/neg test samples: 5, 5

# %%
len(sv_test_df)
# Out:
# 7500

# %%
n_enroll_spks = 3
n_enroll_uttrs = 2
n_pos_test_samples = 20
n_neg_test_samples = 300

# %%
h_enroll_spks = np.random.choice(sv_test_spks, size=n_enroll_spks, replace=False)

# %%
samples_dict = dict()
imposter_uttrs = sv_test_df[~(sv_test_df.spk.isin(h_enroll_spks))].sample(n=n_neg_test_samples)
imposter_uttrs['set'] = 'neg_test'
imposter_uttrs['spk'] = 'imposter'
samples_dict['imposter'] = imposter_uttrs
for spk in h_enroll_spks:
    target_uttrs = sv_test_df[sv_test_df.spk == spk].sample(n=n_enroll_spks+n_pos_test_samples)
    target_uttrs.iloc[:n_enroll_uttrs]['set'] = 'enroll'
    target_uttrs.iloc[n_enroll_uttrs:]['set'] = 'pos_test'
    samples_dict[spk] = target_uttrs
# Out:
# /home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
total_samples = pd.concat([df for df in samples_dict.values()])

# %%
total_samples.to_pickle("trials/human_perf/samples.pkl")

# %%
from pydub import AudioSegment
data_folder = "/home/muncok/DL/dataset/SV_sets/speech_commands/"
result_folder = "trials/human_perf/"

for spk in list(h_enroll_spks) + ['imposter']:
    i = 0
    r_folder = os.path.join(result_folder, spk)
    if not os.path.isdir(r_folder):
        os.makedirs(r_folder)
    for idx, row in samples_dict[spk].iterrows():
        s = AudioSegment.from_wav(os.path.join(data_folder, row.sent, row.file))
        s.export(os.path.join(r_folder, "{}_{}.wav".format(row.set, i)), format='wav')
        i+=1

# %%
pd.read_pickle("./trials")
# Out:
#                       spk    sent                   file       set  label
# dog839572010     imposter     dog  83957201_nohash_0.wav  neg_test    435
# righte3b642170   imposter   right  e3b64217_nohash_0.wav  neg_test   1262
# wowdabf67d90     imposter     wow  dabf67d9_nohash_0.wav  neg_test     83
# yes8d9cc2600     imposter     yes  8d9cc260_nohash_0.wav  neg_test   1556
# stopd1a4fb3f0    imposter    stop  d1a4fb3f_nohash_0.wav  neg_test   1593
# yesc25a032b0     imposter     yes  c25a032b_nohash_0.wav  neg_test    530
# birde65154150    imposter    bird  e6515415_nohash_0.wav  neg_test    453
# onf9273a211      imposter      on  f9273a21_nohash_1.wav  neg_test    388
# treebbb2eb5b0    imposter    tree  bbb2eb5b_nohash_0.wav  neg_test    950
# wowe3e499310     imposter     wow  e3e49931_nohash_0.wav  neg_test    967
# wow5ac04a920     imposter     wow  5ac04a92_nohash_0.wav  neg_test    786
# beda7dd45cf0     imposter     bed  a7dd45cf_nohash_0.wav  neg_test   1099
# stop77def3ee0    imposter    stop  77def3ee_nohash_0.wav  neg_test    358
# bede65154151     imposter     bed  e6515415_nohash_1.wav  neg_test    453
# seven7b3019390   imposter   seven  7b301939_nohash_0.wav  neg_test    976
# tree4a2943412    imposter    tree  4a294341_nohash_2.wav  neg_test   1314
# zerob63fea9e0    imposter    zero  b63fea9e_nohash_0.wav  neg_test   1789
# twoe3b642170     imposter     two  e3b64217_nohash_0.wav  neg_test   1262
# go31270cb21      imposter      go  31270cb2_nohash_1.wav  neg_test    356
# on01648c511      imposter      on  01648c51_nohash_1.wav  neg_test    601
# birdfc94edb00    imposter    bird  fc94edb0_nohash_0.wav  neg_test    126
# sevenf21893dc0   imposter   seven  f21893dc_nohash_0.wav  neg_test   1429
# onf9273a212      imposter      on  f9273a21_nohash_2.wav  neg_test    388
# up8910e5ef0      imposter      up  8910e5ef_nohash_0.wav  neg_test   1675
# happyf1b35ace0   imposter   happy  f1b35ace_nohash_0.wav  neg_test   1559
# off408de0a40     imposter     off  408de0a4_nohash_0.wav  neg_test    348
# treebbbf4fbd0    imposter    tree  bbbf4fbd_nohash_0.wav  neg_test    702
# bedbd8412df0     imposter     bed  bd8412df_nohash_0.wav  neg_test   1731
# zero4abefdf50    imposter    zero  4abefdf5_nohash_0.wav  neg_test    927
# marvinde6eb27c1  imposter  marvin  de6eb27c_nohash_1.wav  neg_test   1140
# ...                   ...     ...                    ...       ...    ...
# treea50a98d20    imposter    tree  a50a98d2_nohash_0.wav  neg_test    426
# fivefb9d6d230    imposter    five  fb9d6d23_nohash_0.wav  neg_test     12
# wow9f7079fe0     imposter     wow  9f7079fe_nohash_0.wav  neg_test   1133
# right723204010   imposter   right  72320401_nohash_0.wav  neg_test    829
# sheila7117fb6d0  imposter  sheila  7117fb6d_nohash_0.wav  neg_test    461
# stopb55a09be2    imposter    stop  b55a09be_nohash_2.wav  neg_test    371
# onab71c9a70      ab71c9a7      on  ab71c9a7_nohash_0.wav    enroll   1198
# fiveab71c9a71    ab71c9a7    five  ab71c9a7_nohash_1.wav    enroll   1198
# sheilaab71c9a71  ab71c9a7  sheila  ab71c9a7_nohash_1.wav  pos_test   1198
# sevenab71c9a72   ab71c9a7   seven  ab71c9a7_nohash_2.wav  pos_test   1198
# noab71c9a70      ab71c9a7      no  ab71c9a7_nohash_0.wav  pos_test   1198
# fiveab71c9a70    ab71c9a7    five  ab71c9a7_nohash_0.wav  pos_test   1198
# twoab71c9a72     ab71c9a7     two  ab71c9a7_nohash_2.wav  pos_test   1198
# sevenab71c9a70   ab71c9a7   seven  ab71c9a7_nohash_0.wav  pos_test   1198
# stop479e64cc0    479e64cc    stop  479e64cc_nohash_0.wav    enroll     53
# right479e64cc0   479e64cc   right  479e64cc_nohash_0.wav    enroll     53
# one479e64cc2     479e64cc     one  479e64cc_nohash_2.wav  pos_test     53
# up479e64cc0      479e64cc      up  479e64cc_nohash_0.wav  pos_test     53
# nine479e64cc0    479e64cc    nine  479e64cc_nohash_0.wav  pos_test     53
# stop479e64cc1    479e64cc    stop  479e64cc_nohash_1.wav  pos_test     53
# sheila479e64cc0  479e64cc  sheila  479e64cc_nohash_0.wav  pos_test     53
# off479e64cc1     479e64cc     off  479e64cc_nohash_1.wav  pos_test     53
# off9bea2ac70     9bea2ac7     off  9bea2ac7_nohash_0.wav    enroll    989
# dog9bea2ac71     9bea2ac7     dog  9bea2ac7_nohash_1.wav    enroll    989
# house9bea2ac72   9bea2ac7   house  9bea2ac7_nohash_2.wav  pos_test    989
# house9bea2ac70   9bea2ac7   house  9bea2ac7_nohash_0.wav  pos_test    989
# left9bea2ac70    9bea2ac7    left  9bea2ac7_nohash_0.wav  pos_test    989
# dog9bea2ac70     9bea2ac7     dog  9bea2ac7_nohash_0.wav  pos_test    989
# no9bea2ac70      9bea2ac7      no  9bea2ac7_nohash_0.wav  pos_test    989
# house9bea2ac71   9bea2ac7   house  9bea2ac7_nohash_1.wav  pos_test    989
#
# [2024 rows x 5 columns]
